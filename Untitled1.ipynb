# %%
import pandas as pd

# %%
split = 3
df = pd.read_csv("Anny_oversampling/DATA/split{}/train/oversampled_train_split{}.csv".format(split,split))

# %%
df[df["diagnosis"]=="B"]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    864496         B        8.726         15.83           55.84      230.9
# 1    864685         B       11.930         21.53           76.53      438.6
# 2    864726         B        8.950         15.76           58.74      245.2
# 6    865137         B       11.410         10.82           73.34      403.3
# 9    865432         B       14.500         10.89           94.28      640.7
# ..      ...       ...          ...           ...             ...        ...
# 353  925277         B       14.590         22.68           96.39      657.1
# 354  925291         B       11.510         23.93           74.52      403.5
# 355  925292         B       14.050         27.15           91.38      600.4
# 356  925311         B       11.200         29.37           70.67      386.0
# 363   92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
df[df["diagnosis"]=="M"]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 3      864729         M        14.87         16.67           98.64      682.5
# 4      864877         M        15.78         22.91          105.70      782.6
# 5      865128         M        17.95         20.01          114.20      982.0
# 7       86517         M        18.66         17.12          121.40     1077.0
# 8      865423         M        24.25         20.20          166.20     1761.0
# ..        ...       ...          ...           ...             ...        ...
# 485    926125         M        20.92         25.09          143.00     1347.0
# 486   8912280         M        16.24         18.77          108.80      805.1
# 487   8810987         M        13.86         16.93           90.96      578.9
# 488  88299702         M        23.21         26.97          153.50     1670.0
# 489   8810955         M        14.19         23.81           92.87      610.7
#
# ...

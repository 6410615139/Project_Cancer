# %%
import pandas as pd

# %%
data = pd.read_csv("raw_data/data.csv")
data_drop = data.drop(labels='Unnamed: 32', axis=1)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(len(data_drop[data_drop["diagnosis"]=="M"]))
print(len(data_drop[data_drop["diagnosis"]=="B"]))
# Out:
# 212
# 357

# %%
357-212
# Out:
# 145

# %%
import csv

# %%
M_data = data_drop[data_drop["diagnosis"]=="M"]
B_data = data_drop[data_drop["diagnosis"]=="B"]

# %%
M_sample = M_data.sample(145)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 328    8953902         M        16.27         20.71          106.90
# 389      90312         M        19.55         23.21          128.90
# 168    8712766         M        17.47         24.68          116.10
# 229     881861         M        12.83         22.33           85.26
# 385      90291         M        14.60         23.29           93.97
# ..         ...       ...          ...           ...             ...
# 489     913535         M        16.69         20.20          107.10
# 263     889403         M        15.61         19.38          100.00
# 9     84501001         M        12.46         24.04           83.97
# 210  881046502         M        20.58         22.14          134.70
# 99      862548         M        14.42         19.77           94.48
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 328      813.7          0.11690           0.13190         0.14780
# ...

# %%
M_concat = pd.concat([M_data, M_sample])
print(len(M_concat))
# Out:
# 357

# %%
357*2
# Out:
# 714

# %%
balance_data = pd.concat([M_concat, B_data])
balance_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B        14.59         22.68           96.39      657.1
# 559    925291         B        11.51         23.93           74.52      403.5
# 560    925292         B        14.05         27.15           91.38      600.4
# 561    925311         B        11.20         29.37           70.67      386.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
balance_data.to_csv("balance_data.csv", index=False)

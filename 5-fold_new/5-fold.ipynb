# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../raw_data/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(labels='Unnamed: 32', axis=1)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# test is first 144 rows
test = df.head(114)
test
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 109    864018         B       11.340         21.26           72.48      396.5
# 110    864033         B        9.777         16.99           62.50      290.2
# 111     86408         B       12.630         20.76           82.15      480.4
# 112     86409         B       14.260         19.65           97.83      629.9
# 113    864292         B       10.510         20.19           68.64      334.2
#
# ...

# %%
# create test set
test.to_csv("../5-fold_new/DATA/test.csv")

# %%
V_fold = df[114:]
V_fold
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 114  864496         B        8.726         15.83           55.84      230.9
# 115  864685         B       11.930         21.53           76.53      438.6
# 116  864726         B        8.950         15.76           58.74      245.2
# 117  864729         M       14.870         16.67           98.64      682.5
# 118  864877         M       15.780         22.91          105.70      782.6
# ..      ...       ...          ...           ...             ...        ...
# 564  926424         M       21.560         22.39          142.00     1479.0
# 565  926682         M       20.130         28.25          131.20     1261.0
# 566  926954         M       16.600         28.08          108.30      858.1
# 567  927241         M       20.600         29.33          140.10     1265.0
# 568   92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
fold = []
first = 114
for i in range(5):
    last = first + 91
    fold.append(df[first:last])
    first = last

# %%
print(len(fold[0]))
print(len(fold[1]))
print(len(fold[2]))
print(len(fold[3]))
print(len(fold[4]))
# Out:
# 91
# 91
# 91
# 91
# 91

# %%
last
# Out:
# 569

# %%
fold[0].to_csv("../5-fold_new/fold1.csv", index=False)
fold[1].to_csv("../5-fold_new/fold2.csv", index=False)
fold[2].to_csv("../5-fold_new/fold3.csv", index=False)
fold[3].to_csv("../5-fold_new/fold4.csv", index=False)
fold[4].to_csv("../5-fold_new/fold5.csv", index=False)

# %%
fold[0]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 114  864496         B        8.726         15.83           55.84      230.9
# 115  864685         B       11.930         21.53           76.53      438.6
# 116  864726         B        8.950         15.76           58.74      245.2
# 117  864729         M       14.870         16.67           98.64      682.5
# 118  864877         M       15.780         22.91          105.70      782.6
# ..      ...       ...          ...           ...             ...        ...
# 200  877501         B       12.230         19.56           78.54      461.0
# 201  877989         M       17.540         19.32          115.10      951.6
# 202  878796         M       23.290         26.67          158.90     1685.0
# 203   87880         M       13.810         23.75           91.56      597.8
# 204   87930         B       12.470         18.60           81.09      481.9
#
# ...

# %%
fold[1]
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 205   879523         M       15.120         16.68           98.78      716.6
# 206   879804         B        9.876         17.27           62.92      295.4
# 207   879830         M       17.010         20.26          109.70      904.3
# 208  8810158         B       13.110         22.54           87.02      529.4
# 209  8810436         B       15.270         12.91           98.17      725.5
# ..       ...       ...          ...           ...             ...        ...
# 291     8915         B       14.960         19.10           97.03      687.3
# 292   891670         B       12.950         16.02           83.14      513.7
# 293   891703         B       11.850         17.46           75.54      432.7
# 294   891716         B       12.720         13.78           81.78      492.1
# 295   891923         B       13.770         13.27           88.06      582.7
#
# ...

# %%
fold[2]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 296  891936         B        10.91         12.35           69.14      363.7
# 297  892189         M        11.76         18.14           75.00      431.1
# 298  892214         B        14.26         18.17           91.22      633.1
# 299  892399         B        10.51         23.09           66.85      334.2
# 300  892438         M        19.53         18.90          129.50     1217.0
# ..      ...       ...          ...           ...             ...        ...
# 382   90250         B        12.05         22.72           78.75      447.8
# 383   90251         B        12.39         17.48           80.64      462.9
# 384  902727         B        13.28         13.72           85.79      541.8
# 385   90291         M        14.60         23.29           93.97      664.7
# 386  902975         B        12.21         14.09           78.78      462.0
#
# ...

# %%
fold[3]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 387    902976         B       13.880         16.16           88.37      596.6
# 388    903011         B       11.270         15.50           73.38      392.0
# 389     90312         M       19.550         23.21          128.90     1174.0
# 390  90317302         B       10.260         12.22           65.75      321.6
# 391    903483         B        8.734         16.84           55.27      234.3
# ..        ...       ...          ...           ...             ...        ...
# 473   9113846         B       12.270         29.97           77.42      465.4
# 474    911391         B       10.880         15.62           70.41      358.9
# 475    911408         B       12.830         15.73           82.89      506.9
# 476    911654         B       14.200         20.53           92.41      618.4
# 477    911673         B       13.900         16.62           88.97      599.4
#
# ...

# %%
fold[4]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 478  911685         B        11.49         14.59           73.99      404.9
# 479  911916         M        16.25         19.51          109.80      815.8
# 480  912193         B        12.16         18.03           78.29      455.3
# 481   91227         B        13.90         19.24           88.73      602.9
# 482  912519         B        13.47         14.06           87.32      546.3
# ..      ...       ...          ...           ...             ...        ...
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
# ...
